# %% [markdown]
# # Apprentissage Semi-Supervisé
#
# On se propose dans ce TP d'illustrer certaines techniques d'apprentissage semi-supervisé vues en cours.
#
# Dans tout ce qui suit, on considère que l'on dispose d'un ensemble de données $x_{lab}$ labellisées et d'un ensemble de donnés $x_{unlab}$ non labellisées.

# %% [markdown]
# ## Datasets

# %% [markdown]
# Commencez par exécuter ces codes qui vos permettront de charger les datasets que nous allons utiliser et de les séparer en données labellisées et non labellisées, ainsi qu'en données de test.

# %% [markdown]
# ### Dataset des deux clusters

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

def generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250):
  num_samples = num_lab + num_unlab + num_test
  # Génération de 1000 données du dataset des 2 lunes
  x, y = datasets.make_blobs(n_samples=[round(num_samples/2), round(num_samples/2)], n_features=2, center_box=(- 3, 3), random_state=1)

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=num_test/num_samples, random_state=1)
  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=num_unlab/(num_unlab+num_lab), random_state=6)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test

# %%
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250)

print(x_train_lab.shape, x_train_unlab.shape, x_test.shape)
print(y_train_lab.shape, y_train_unlab.shape, y_test.shape)

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], color=(0.5,0.5,0.5), marker='.', linestyle=' ')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], color=(0.5,0.5,0.5), marker='.', linestyle=' ')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()
# Out:
# (10, 2) (740, 2) (250, 2)
# (10,) (740,) (250,)

# %% [markdown]
# ### Dataset des 2 lunes

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1xb_gasBJ6sEmbyvCWTnVEAsbspyDCyFL">
# <caption><center> Figure 1: Comparaison de différents algorithmes semi-supervisés sur le dataset des 2 lunes</center></caption>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

def generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250):
  num_samples = num_lab + num_unlab + num_test
  # Génération de 1000 données du dataset des 2 lunes
  x, y = datasets.make_moons(n_samples=num_samples, noise=0.1, random_state=1)

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=num_test/num_samples, random_state=1)
  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=num_unlab/(num_unlab+num_lab), random_state=6)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test

# %%
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)

print(x_train_lab.shape, x_train_unlab.shape, x_test.shape)
print(y_train_lab.shape, y_train_unlab.shape, y_test.shape)

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()
# Out:
# (10, 2) (740, 2) (250, 2)
# (10,) (740,) (250,)

# %% [markdown]
# ## Modèles

# %% [markdown]
# Nous allons dès maintenant préparer les modèles que nous utiliserons dans la suite.
#
# **Travail à faire** Complétez les modèles ci-dessous :

# %% [markdown]
# Pour le dataset des 2 clusters, un simple perceptron monocouche suffira :

# %%
from tensorflow.keras.layers import *
from tensorflow.keras import Model, Input
# A COMPLETER
# Ici, écrire un simple perceptron monocouche
# Une seule couche dense, AVEC LE BON NOMBRE DE NEURONES EN ENTREE ET EN SORTIE !
def create_model_2clusters():

  inputs = Input(shape=2)
  outputs = Dense(1, activation='sigmoid')(inputs)
  model = Model(inputs=inputs, outputs=outputs)

  return model

# %% [markdown]
# Pour le dataset des 2 lunes, implémentez un perceptron multi-couches à une couche cachée, par exemple de 20 neurones.

# %%
# A COMPLETER
# Ici, écrire un perceptron multi-couches à une seule couche cachée comprenant 20 neurones
def create_model_2moons():

  inputs = keras.Input(shape=(2,))
  x = Dense(20, activation="relu")(inputs)
  outputs = Dense(1, activation="sigmoid")(x)
  model = Model(inputs=inputs, outputs=outputs)

  return model

# %% [markdown]
# ## Apprentissage supervisé

# %% [markdown]
# Commencez par bien lire le code ci-dessous, qui vous permet de mettre en place un apprentissage supervisé en détaillant la boucle d'apprentissage (de l'algorithme de descente de gradient stochastique). Cela nous permettra d'avoir plus de contrôle dans la suite pour implémenter les algorithmes semi-supervisés. Cela vous fournira également une base contre laquelle comparer les algorithmes semi-supervisés.
#
# En quelques mots, l'algorithme est organisé autour d'une double boucle : une sur les *epochs*, et la 2nde sur les *mini-batches*.
#
# Pour chaque nouveau batch de données, on réalise la succession d'étapes suivantes dans un bloc **GradientTape** qui permet le calcul automatique des gradients :
#
#
# 1.   Prédiction de la sortie du modèle sur les données du batch
# 2.   Calcul de la fonction de perte entre sortie du réseau et labels réels associés aux élements du batch
# 3.   Calcul des gradients de la perte par rapport aux paramètres du réseau (par différentiation automatique)
# 4.   Mise à jour des paramètres grâce aux gradients calculés.

# %% [markdown]
# ### Dataset des 2 clusters

# %%
import tensorflow as tf
from tensorflow import keras
import math

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2clusters()

# Hyperparamètres de l'apprentissage
epochs = 150
batch_size = 16
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices = np.arange(x_train_lab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices[step*batch_size: (step+1)*batch_size]]
    y_batch = y_train_lab[indices[step*batch_size: (step+1)*batch_size]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch

      # Calcul de la fonction de perte sur ce batch
      loss_value = loss_fn(y_batch, y_pred)

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_states()
  test_acc_metric.reset_states()
# Out:
# Epoch    0 : Loss : 1.0956, Acc : 0.3000, Test Acc : 0.2440
# Epoch    1 : Loss : 1.0743, Acc : 0.3000, Test Acc : 0.2480
# Epoch    2 : Loss : 1.0534, Acc : 0.3000, Test Acc : 0.2520
# Epoch    3 : Loss : 1.0327, Acc : 0.3000, Test Acc : 0.2520
# Epoch    4 : Loss : 1.0122, Acc : 0.3000, Test Acc : 0.2520
# Epoch    5 : Loss : 0.9921, Acc : 0.3000, Test Acc : 0.2560
# Epoch    6 : Loss : 0.9723, Acc : 0.3000, Test Acc : 0.2560
# Epoch    7 : Loss : 0.9528, Acc : 0.3000, Test Acc : 0.2560
# Epoch    8 : Loss : 0.9336, Acc : 0.3000, Test Acc : 0.2800
# Epoch    9 : Loss : 0.9147, Acc : 0.3000, Test Acc : 0.2800
# Epoch  124 : Loss : 0.2081, Acc : 1.0000, Test Acc : 0.9520
# Epoch  125 : Loss : 0.2066, Acc : 1.0000, Test Acc : 0.9520
# Epoch  126 : Loss : 0.2052, Acc : 1.0000, Test Acc : 0.9520
# Epoch  127 : Loss : 0.2038, Acc : 1.0000, Test Acc : 0.9520
# Epoch  128 : Loss : 0.2025, Acc : 1.0000, Test Acc : 0.9520
# Epoch  129 : Loss : 0.2011, Acc : 1.0000, Test Acc : 0.9520
# Epoch  130 : Loss : 0.1998, Acc : 1.0000, Test Acc : 0.9520
# Epoch  131 : Loss : 0.1985, Acc : 1.0000, Test Acc : 0.9520
# Epoch  132 : Loss : 0.1972, Acc : 1.0000, Test Acc : 0.9520
# Epoch  133 : Loss : 0.1959, Acc : 1.0000, Test Acc : 0.9520
# Epoch  134 : Loss : 0.1947, Acc : 1.0000, Test Acc : 0.9520
# Epoch  135 : Loss : 0.1934, Acc : 1.0000, Test Acc : 0.9520
# Epoch  136 : Loss : 0.1922, Acc : 1.0000, Test Acc : 0.9520
# Epoch  137 : Loss : 0.1910, Acc : 1.0000, Test Acc : 0.9520
# Epoch  138 : Loss : 0.1898, Acc : 1.0000, Test Acc : 0.9520
# Epoch  139 : Loss : 0.1886, Acc : 1.0000, Test Acc : 0.9520
# Epoch  140 : Loss : 0.1875, Acc : 1.0000, Test Acc : 0.9520
# Epoch  141 : Loss : 0.1863, Acc : 1.0000, Test Acc : 0.9520
# Epoch  142 : Loss : 0.1852, Acc : 1.0000, Test Acc : 0.9520
# Epoch  143 : Loss : 0.1841, Acc : 1.0000, Test Acc : 0.9520
# Epoch  144 : Loss : 0.1830, Acc : 1.0000, Test Acc : 0.9520
# Epoch  145 : Loss : 0.1819, Acc : 1.0000, Test Acc : 0.9520
# Epoch  146 : Loss : 0.1808, Acc : 1.0000, Test Acc : 0.9520
# Epoch  147 : Loss : 0.1798, Acc : 1.0000, Test Acc : 0.9520
# Epoch  148 : Loss : 0.1787, Acc : 1.0000, Test Acc : 0.9520
# Epoch  149 : Loss : 0.1777, Acc : 1.0000, Test Acc : 0.9520

# %%
from mlxtend.plotting import plot_decision_regions

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 15s 2ms/step

# %% [markdown]
# ### Dataset des 2 lunes

# %% [markdown]
# **Travail à faire** : Mettez en place le même apprentissage pour le dataset des 2 lunes.

# %%
import tensorflow as tf
from tensorflow import keras
import math

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2moons()

# Hyperparamètres de l'apprentissage
epochs = 150
batch_size = 16
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices = np.arange(x_train_lab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices[step*batch_size: (step+1)*batch_size]]
    y_batch = y_train_lab[indices[step*batch_size: (step+1)*batch_size]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch

      # Calcul de la fonction de perte sur ce batch
      loss_value = loss_fn(y_batch, y_pred)

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_states()
  test_acc_metric.reset_states()
# Out:
# WARNING:tensorflow:5 out of the last 601 calls to <function _BaseOptimizer._update_step_xla at 0x7bd7aa7fa8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch    0 : Loss : 0.7107, Acc : 0.6000, Test Acc : 0.5120
# Epoch    1 : Loss : 0.6887, Acc : 0.7000, Test Acc : 0.5120
# Epoch    2 : Loss : 0.6684, Acc : 0.7000, Test Acc : 0.5120
# Epoch    3 : Loss : 0.6495, Acc : 0.7000, Test Acc : 0.5120
# Epoch    4 : Loss : 0.6318, Acc : 0.7000, Test Acc : 0.5120
# Epoch   43 : Loss : 0.3133, Acc : 0.8000, Test Acc : 0.8520
# Epoch   44 : Loss : 0.3085, Acc : 0.8000, Test Acc : 0.8520
# Epoch   45 : Loss : 0.3040, Acc : 0.8000, Test Acc : 0.8480
# Epoch   46 : Loss : 0.2996, Acc : 0.8000, Test Acc : 0.8480
# Epoch   47 : Loss : 0.2955, Acc : 0.8000, Test Acc : 0.8440
# Epoch   48 : Loss : 0.2915, Acc : 0.8000, Test Acc : 0.8480
# Epoch   49 : Loss : 0.2876, Acc : 0.8000, Test Acc : 0.8480
# Epoch   50 : Loss : 0.2839, Acc : 0.8000, Test Acc : 0.8480
# Epoch   51 : Loss : 0.2802, Acc : 0.8000, Test Acc : 0.8480
# Epoch   52 : Loss : 0.2766, Acc : 0.8000, Test Acc : 0.8520
# Epoch   53 : Loss : 0.2729, Acc : 0.8000, Test Acc : 0.8560
# Epoch   54 : Loss : 0.2694, Acc : 0.8000, Test Acc : 0.8640
# Epoch   55 : Loss : 0.2660, Acc : 0.8000, Test Acc : 0.8640
# Epoch   56 : Loss : 0.2628, Acc : 0.8000, Test Acc : 0.8680
# Epoch   57 : Loss : 0.2596, Acc : 0.8000, Test Acc : 0.8760
# Epoch   58 : Loss : 0.2564, Acc : 0.8000, Test Acc : 0.8760
# Epoch   59 : Loss : 0.2533, Acc : 0.8000, Test Acc : 0.8760
# Epoch   60 : Loss : 0.2501, Acc : 0.8000, Test Acc : 0.8760
# Epoch   61 : Loss : 0.2469, Acc : 0.8000, Test Acc : 0.8800
# Epoch   62 : Loss : 0.2437, Acc : 0.8000, Test Acc : 0.8800
# Epoch   63 : Loss : 0.2406, Acc : 0.8000, Test Acc : 0.8800
# Epoch   64 : Loss : 0.2374, Acc : 0.8000, Test Acc : 0.8840
# Epoch   65 : Loss : 0.2343, Acc : 0.8000, Test Acc : 0.8840
# Epoch   66 : Loss : 0.2313, Acc : 0.8000, Test Acc : 0.8880
# Epoch   67 : Loss : 0.2282, Acc : 0.8000, Test Acc : 0.8880
# Epoch   68 : Loss : 0.2254, Acc : 0.8000, Test Acc : 0.9000
# Epoch   69 : Loss : 0.2227, Acc : 0.8000, Test Acc : 0.9040
# Epoch   70 : Loss : 0.2199, Acc : 0.8000, Test Acc : 0.9040
# Epoch   71 : Loss : 0.2180, Acc : 0.8000, Test Acc : 0.9080
# Epoch   72 : Loss : 0.2161, Acc : 0.8000, Test Acc : 0.9120
# Epoch   73 : Loss : 0.2142, Acc : 0.8000, Test Acc : 0.9120
# Epoch   74 : Loss : 0.2123, Acc : 0.8000, Test Acc : 0.9120
# Epoch   75 : Loss : 0.2104, Acc : 0.8000, Test Acc : 0.9080
# Epoch   76 : Loss : 0.2085, Acc : 0.8000, Test Acc : 0.9080
# Epoch   77 : Loss : 0.2067, Acc : 0.8000, Test Acc : 0.9080
# Epoch   78 : Loss : 0.2050, Acc : 0.8000, Test Acc : 0.9080
# Epoch   79 : Loss : 0.2033, Acc : 0.8000, Test Acc : 0.9040
# Epoch   80 : Loss : 0.2016, Acc : 0.8000, Test Acc : 0.9040
# Epoch  119 : Loss : 0.1607, Acc : 0.9000, Test Acc : 0.8760
# Epoch  120 : Loss : 0.1600, Acc : 0.9000, Test Acc : 0.8720
# Epoch  121 : Loss : 0.1592, Acc : 0.9000, Test Acc : 0.8720
# Epoch  122 : Loss : 0.1585, Acc : 0.9000, Test Acc : 0.8760
# Epoch  123 : Loss : 0.1578, Acc : 0.9000, Test Acc : 0.8760
# Epoch  124 : Loss : 0.1571, Acc : 0.9000, Test Acc : 0.8760
# Epoch  125 : Loss : 0.1564, Acc : 0.9000, Test Acc : 0.8760
# Epoch  126 : Loss : 0.1557, Acc : 0.9000, Test Acc : 0.8720
# Epoch  127 : Loss : 0.1551, Acc : 0.9000, Test Acc : 0.8720
# Epoch  128 : Loss : 0.1543, Acc : 0.9000, Test Acc : 0.8640
# Epoch  129 : Loss : 0.1536, Acc : 0.9000, Test Acc : 0.8640
# Epoch  130 : Loss : 0.1530, Acc : 0.9000, Test Acc : 0.8640
# Epoch  131 : Loss : 0.1523, Acc : 0.9000, Test Acc : 0.8640
# Epoch  132 : Loss : 0.1516, Acc : 0.9000, Test Acc : 0.8640
# Epoch  133 : Loss : 0.1509, Acc : 0.9000, Test Acc : 0.8640
# Epoch  134 : Loss : 0.1501, Acc : 0.9000, Test Acc : 0.8640
# Epoch  135 : Loss : 0.1493, Acc : 0.9000, Test Acc : 0.8640
# Epoch  136 : Loss : 0.1487, Acc : 0.9000, Test Acc : 0.8640
# Epoch  137 : Loss : 0.1479, Acc : 0.9000, Test Acc : 0.8640
# Epoch  138 : Loss : 0.1472, Acc : 0.9000, Test Acc : 0.8640
# Epoch  139 : Loss : 0.1465, Acc : 0.9000, Test Acc : 0.8640
# Epoch  140 : Loss : 0.1458, Acc : 0.9000, Test Acc : 0.8640
# Epoch  141 : Loss : 0.1451, Acc : 0.9000, Test Acc : 0.8640
# Epoch  142 : Loss : 0.1444, Acc : 0.9000, Test Acc : 0.8640
# Epoch  143 : Loss : 0.1436, Acc : 0.9000, Test Acc : 0.8640
# Epoch  144 : Loss : 0.1429, Acc : 0.9000, Test Acc : 0.8640
# Epoch  145 : Loss : 0.1422, Acc : 0.9000, Test Acc : 0.8640
# Epoch  146 : Loss : 0.1415, Acc : 0.9000, Test Acc : 0.8640
# Epoch  147 : Loss : 0.1407, Acc : 0.9000, Test Acc : 0.8640
# Epoch  148 : Loss : 0.1400, Acc : 0.9000, Test Acc : 0.8640
# Epoch  149 : Loss : 0.1392, Acc : 0.9000, Test Acc : 0.8640

# %%
from mlxtend.plotting import plot_decision_regions

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 14s 1ms/step

# %% [markdown]
# # Minimisation de l'entropie

# %% [markdown]
# Nous allons dans cette partie implémenter l'algorithme de minimisation de l'entropie de prédiction du modèle sur les données non labellisées, conjointement à la minimisation de l'entropie croisée sur les données labellisées.
#
# Pour commencer, implémentez la fonction de coût qui calcule l'entropie $H$ des prédictions du réseau $\hat{y}$ :
# $$ H(\hat{y}) = - ∑_{i=1}^N \hat{y}_i log(\hat{y}_i) $$
#
# Pour les exemples simples des datasets des 2 clusters et des 2 lunes, il faut implémenter une entropie binaire ! (plus tard, sur MNIST, il faudra implémenter une version multi-classe de l'entropie)

# %%
import tensorflow as tf

# Calcul de l'entropie de y_pred
# A COMPLETER
def binary_entropy_loss(y_pred):
    epsilon = 1e-7
    y_pred_chap = tf.clip_by_value(y_pred, epsilon, 1 - epsilon)
    binary_entropy = -y_pred_chap * tf.math.log(y_pred_chap) - (1 - y_pred_chap) * tf.math.log(1 - y_pred_chap)
    return tf.reduce_mean(binary_entropy)

# %% [markdown]
# **ATTENTION: il faut gérer manuellement les cas où $\hat{y}$ vaudrait 0 ou 1, ce qui donnerait une valeur *NaN* à la fonction de coût.** Pour cela, vous pouvez utiliser la fonction [clip_by_value](https://www.tensorflow.org/api_docs/python/tf/clip_by_value) qui va vous permettre de circonscrire les valeurs de $\hat{y}$ à $[\epsilon , 1 - \epsilon ] $ (vous pouvez par exemple utiliser la valeur $\epsilon = 10^{-7}$).

# %% [markdown]
# **ATTENTION 2**: cette fonction de coût doit être dérivable et doit donc être implémentée uniquement en utilisant des fonctions de *Tensorflow* (et surtout pas *Numpy*)

# %% [markdown]
# **Travail à faire** : Reprenez maintenant la boucle d'apprentissage supervisé et introduisez la minimisation d'entropie pour régulariser l'apprentissage.
#
# La difficulté principale va être l'introduction des données non labellisées dans la boucle. Ainsi, un batch devra maintenant être composé de données labellisées et non labellisées. Je vous suggère de conserver le même nombre de données labellisées par batch que précédemment (i.e. 16) et de prendre un plus grand nombre de données non labellisées, par exemple 90.
#
# N'oubliez pas également d'introduire un hyperparamètre λ pour contrôler l'équilibre entre perte supervisée et non supervisée. Utilisez un λ constant dans un premier temps, et testez ensuite des variantes qui consisteraient à augmenter progressivement sa valeur au fil des epochs.
#
# La fonction objectif à minimiser aura donc la forme :
# $$  J = \sum_{(x,y) \in \mathcal{L}} CE(y, \hat{y}) + \lambda \sum_{x \in \mathcal{U}} H(\hat{y})	$$

# %%
import tensorflow as tf
from tensorflow import keras
import math

lambda_t = 0

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2clusters()

# Hyperparamètres de l'apprentissage
epochs = 150
batch_size = 16
batch_size_unlab = 90
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices_lab = np.arange(x_train_lab.shape[0])
indices_unlab = np.arange(x_train_unlab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices_lab[step*batch_size: (step+1)*batch_size]]
    y_batch = y_train_lab[indices_lab[step*batch_size: (step+1)*batch_size]]
    x_batch_unlab = x_train_unlab[indices_unlab[step*batch_size_unlab: (step+1)*batch_size_unlab]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch
      y_pred_unlab = model(x_batch_unlab, training=True)

      # Calcul de la fonction de perte sur ce batch
      sup_term = loss_fn(y_batch, y_pred)
      unsup_term = binary_entropy_loss(y_pred_unlab)

      loss_value = sup_term + unsup_term

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_states()
  test_acc_metric.reset_states()

  # Mise à jour du paramètre de contrôle de l'importance de la régularisation non-supervisée
  # Il augmente progressivement !
  if lambda_t < 1:
    if epoch > 100:
      lambda_t = lambda_t + 0.01
# Out:
# Epoch    0 : Loss : 0.4665, Acc : 0.9000, Test Acc : 0.8920
# Epoch    1 : Loss : 0.4622, Acc : 0.9000, Test Acc : 0.8960
# Epoch    2 : Loss : 0.4579, Acc : 0.9000, Test Acc : 0.9000
# Epoch    3 : Loss : 0.4537, Acc : 0.9000, Test Acc : 0.9000
# Epoch    4 : Loss : 0.4496, Acc : 0.9000, Test Acc : 0.9000
# Epoch    5 : Loss : 0.4455, Acc : 0.9000, Test Acc : 0.9000
# Epoch    6 : Loss : 0.4415, Acc : 0.9000, Test Acc : 0.9000
# Epoch    7 : Loss : 0.4376, Acc : 0.9000, Test Acc : 0.9000
# Epoch    8 : Loss : 0.4337, Acc : 0.9000, Test Acc : 0.9000
# Epoch    9 : Loss : 0.4299, Acc : 0.9000, Test Acc : 0.9040
# Epoch   10 : Loss : 0.4261, Acc : 0.9000, Test Acc : 0.9000
# Epoch   11 : Loss : 0.4224, Acc : 0.9000, Test Acc : 0.9000
# Epoch   12 : Loss : 0.4187, Acc : 0.9000, Test Acc : 0.9000
# Epoch   13 : Loss : 0.4151, Acc : 0.9000, Test Acc : 0.9000
# Epoch   14 : Loss : 0.4115, Acc : 0.9000, Test Acc : 0.9000
# Epoch   15 : Loss : 0.4081, Acc : 0.9000, Test Acc : 0.9000
# Epoch   16 : Loss : 0.4046, Acc : 0.9000, Test Acc : 0.9000
# Epoch   17 : Loss : 0.4012, Acc : 0.9000, Test Acc : 0.9080
# Epoch   18 : Loss : 0.3979, Acc : 0.9000, Test Acc : 0.9120
# Epoch   19 : Loss : 0.3946, Acc : 0.9000, Test Acc : 0.9160
# Epoch   20 : Loss : 0.3914, Acc : 0.9000, Test Acc : 0.9160
# Epoch   21 : Loss : 0.3882, Acc : 0.9000, Test Acc : 0.9160
# Epoch   22 : Loss : 0.3851, Acc : 0.9000, Test Acc : 0.9200
# Epoch   23 : Loss : 0.3820, Acc : 0.9000, Test Acc : 0.9200
# Epoch   24 : Loss : 0.3790, Acc : 1.0000, Test Acc : 0.9200
# Epoch   25 : Loss : 0.3760, Acc : 1.0000, Test Acc : 0.9200
# Epoch   26 : Loss : 0.3730, Acc : 1.0000, Test Acc : 0.9200
# Epoch   27 : Loss : 0.3701, Acc : 1.0000, Test Acc : 0.9200
# Epoch   28 : Loss : 0.3673, Acc : 1.0000, Test Acc : 0.9200
# Epoch   29 : Loss : 0.3645, Acc : 1.0000, Test Acc : 0.9200
# Epoch   30 : Loss : 0.3617, Acc : 1.0000, Test Acc : 0.9200
# Epoch   31 : Loss : 0.3590, Acc : 1.0000, Test Acc : 0.9240
# Epoch   32 : Loss : 0.3563, Acc : 1.0000, Test Acc : 0.9240
# Epoch   33 : Loss : 0.3537, Acc : 1.0000, Test Acc : 0.9240
# Epoch   34 : Loss : 0.3510, Acc : 1.0000, Test Acc : 0.9240
# Epoch   35 : Loss : 0.3485, Acc : 1.0000, Test Acc : 0.9280
# Epoch   36 : Loss : 0.3459, Acc : 1.0000, Test Acc : 0.9360
# Epoch   37 : Loss : 0.3435, Acc : 1.0000, Test Acc : 0.9360
# Epoch   38 : Loss : 0.3410, Acc : 1.0000, Test Acc : 0.9360
# Epoch   39 : Loss : 0.3386, Acc : 1.0000, Test Acc : 0.9360
# Epoch   40 : Loss : 0.3362, Acc : 1.0000, Test Acc : 0.9360
# Epoch   41 : Loss : 0.3338, Acc : 1.0000, Test Acc : 0.9360
# Epoch   42 : Loss : 0.3315, Acc : 1.0000, Test Acc : 0.9360
# Epoch   43 : Loss : 0.3292, Acc : 1.0000, Test Acc : 0.9360
# Epoch   44 : Loss : 0.3270, Acc : 1.0000, Test Acc : 0.9360
# Epoch   45 : Loss : 0.3247, Acc : 1.0000, Test Acc : 0.9360
# Epoch   46 : Loss : 0.3225, Acc : 1.0000, Test Acc : 0.9400
# Epoch   47 : Loss : 0.3204, Acc : 1.0000, Test Acc : 0.9400
# Epoch   48 : Loss : 0.3182, Acc : 1.0000, Test Acc : 0.9400
# Epoch   49 : Loss : 0.3161, Acc : 1.0000, Test Acc : 0.9440
# Epoch   50 : Loss : 0.3140, Acc : 1.0000, Test Acc : 0.9440
# Epoch   51 : Loss : 0.3120, Acc : 1.0000, Test Acc : 0.9440
# Epoch   52 : Loss : 0.3099, Acc : 1.0000, Test Acc : 0.9480
# Epoch   53 : Loss : 0.3079, Acc : 1.0000, Test Acc : 0.9480
# Epoch   54 : Loss : 0.3059, Acc : 1.0000, Test Acc : 0.9480
# Epoch   55 : Loss : 0.3040, Acc : 1.0000, Test Acc : 0.9480
# Epoch   56 : Loss : 0.3021, Acc : 1.0000, Test Acc : 0.9480
# Epoch   57 : Loss : 0.3002, Acc : 1.0000, Test Acc : 0.9520
# Epoch   58 : Loss : 0.2983, Acc : 1.0000, Test Acc : 0.9520
# Epoch   59 : Loss : 0.2964, Acc : 1.0000, Test Acc : 0.9520
# Epoch   60 : Loss : 0.2946, Acc : 1.0000, Test Acc : 0.9520
# Epoch   61 : Loss : 0.2928, Acc : 1.0000, Test Acc : 0.9520
# Epoch   62 : Loss : 0.2910, Acc : 1.0000, Test Acc : 0.9520
# Epoch   63 : Loss : 0.2892, Acc : 1.0000, Test Acc : 0.9520
# Epoch   64 : Loss : 0.2874, Acc : 1.0000, Test Acc : 0.9520
# Epoch   65 : Loss : 0.2857, Acc : 1.0000, Test Acc : 0.9520
# Epoch   66 : Loss : 0.2840, Acc : 1.0000, Test Acc : 0.9520
# Epoch   67 : Loss : 0.2823, Acc : 1.0000, Test Acc : 0.9520
# Epoch   68 : Loss : 0.2806, Acc : 1.0000, Test Acc : 0.9520
# Epoch   69 : Loss : 0.2790, Acc : 1.0000, Test Acc : 0.9520
# Epoch   70 : Loss : 0.2774, Acc : 1.0000, Test Acc : 0.9520
# Epoch   71 : Loss : 0.2758, Acc : 1.0000, Test Acc : 0.9520
# Epoch   72 : Loss : 0.2742, Acc : 1.0000, Test Acc : 0.9520
# Epoch   73 : Loss : 0.2726, Acc : 1.0000, Test Acc : 0.9520
# Epoch   74 : Loss : 0.2710, Acc : 1.0000, Test Acc : 0.9520
# Epoch   75 : Loss : 0.2695, Acc : 1.0000, Test Acc : 0.9520
# Epoch   76 : Loss : 0.2680, Acc : 1.0000, Test Acc : 0.9520
# Epoch   77 : Loss : 0.2664, Acc : 1.0000, Test Acc : 0.9520
# Epoch   78 : Loss : 0.2650, Acc : 1.0000, Test Acc : 0.9520
# Epoch   79 : Loss : 0.2635, Acc : 1.0000, Test Acc : 0.9480
# Epoch   80 : Loss : 0.2620, Acc : 1.0000, Test Acc : 0.9480
# Epoch   81 : Loss : 0.2606, Acc : 1.0000, Test Acc : 0.9480
# Epoch   82 : Loss : 0.2592, Acc : 1.0000, Test Acc : 0.9480
# Epoch   83 : Loss : 0.2578, Acc : 1.0000, Test Acc : 0.9480
# Epoch   84 : Loss : 0.2564, Acc : 1.0000, Test Acc : 0.9520
# Epoch   85 : Loss : 0.2550, Acc : 1.0000, Test Acc : 0.9520
# Epoch   86 : Loss : 0.2536, Acc : 1.0000, Test Acc : 0.9520
# Epoch   87 : Loss : 0.2523, Acc : 1.0000, Test Acc : 0.9520
# Epoch   88 : Loss : 0.2509, Acc : 1.0000, Test Acc : 0.9520
# Epoch   89 : Loss : 0.2496, Acc : 1.0000, Test Acc : 0.9520
# Epoch   90 : Loss : 0.2483, Acc : 1.0000, Test Acc : 0.9520
# Epoch   91 : Loss : 0.2470, Acc : 1.0000, Test Acc : 0.9520
# Epoch   92 : Loss : 0.2457, Acc : 1.0000, Test Acc : 0.9520
# Epoch   93 : Loss : 0.2445, Acc : 1.0000, Test Acc : 0.9520
# Epoch   94 : Loss : 0.2432, Acc : 1.0000, Test Acc : 0.9520
# Epoch   95 : Loss : 0.2420, Acc : 1.0000, Test Acc : 0.9520
# Epoch   96 : Loss : 0.2407, Acc : 1.0000, Test Acc : 0.9520
# Epoch   97 : Loss : 0.2395, Acc : 1.0000, Test Acc : 0.9560
# Epoch   98 : Loss : 0.2383, Acc : 1.0000, Test Acc : 0.9520
# Epoch   99 : Loss : 0.2371, Acc : 1.0000, Test Acc : 0.9520
# Epoch  100 : Loss : 0.2360, Acc : 1.0000, Test Acc : 0.9520
# Epoch  101 : Loss : 0.2348, Acc : 1.0000, Test Acc : 0.9520
# Epoch  102 : Loss : 0.2336, Acc : 1.0000, Test Acc : 0.9520
# Epoch  103 : Loss : 0.2325, Acc : 1.0000, Test Acc : 0.9520
# Epoch  104 : Loss : 0.2314, Acc : 1.0000, Test Acc : 0.9520
# Epoch  105 : Loss : 0.2303, Acc : 1.0000, Test Acc : 0.9520
# Epoch  106 : Loss : 0.2292, Acc : 1.0000, Test Acc : 0.9520
# Epoch  107 : Loss : 0.2281, Acc : 1.0000, Test Acc : 0.9520
# Epoch  108 : Loss : 0.2270, Acc : 1.0000, Test Acc : 0.9520
# Epoch  109 : Loss : 0.2259, Acc : 1.0000, Test Acc : 0.9520
# Epoch  110 : Loss : 0.2248, Acc : 1.0000, Test Acc : 0.9520
# Epoch  111 : Loss : 0.2238, Acc : 1.0000, Test Acc : 0.9520
# Epoch  112 : Loss : 0.2228, Acc : 1.0000, Test Acc : 0.9520
# Epoch  113 : Loss : 0.2217, Acc : 1.0000, Test Acc : 0.9520
# Epoch  114 : Loss : 0.2207, Acc : 1.0000, Test Acc : 0.9520
# Epoch  115 : Loss : 0.2197, Acc : 1.0000, Test Acc : 0.9520
# Epoch  116 : Loss : 0.2187, Acc : 1.0000, Test Acc : 0.9520
# Epoch  117 : Loss : 0.2177, Acc : 1.0000, Test Acc : 0.9520
# Epoch  118 : Loss : 0.2167, Acc : 1.0000, Test Acc : 0.9520
# Epoch  119 : Loss : 0.2158, Acc : 1.0000, Test Acc : 0.9520
# Epoch  120 : Loss : 0.2148, Acc : 1.0000, Test Acc : 0.9520
# Epoch  121 : Loss : 0.2138, Acc : 1.0000, Test Acc : 0.9520
# Epoch  122 : Loss : 0.2129, Acc : 1.0000, Test Acc : 0.9520
# Epoch  123 : Loss : 0.2120, Acc : 1.0000, Test Acc : 0.9520
# Epoch  124 : Loss : 0.2110, Acc : 1.0000, Test Acc : 0.9520
# Epoch  125 : Loss : 0.2101, Acc : 1.0000, Test Acc : 0.9520
# Epoch  126 : Loss : 0.2092, Acc : 1.0000, Test Acc : 0.9520
# Epoch  127 : Loss : 0.2083, Acc : 1.0000, Test Acc : 0.9520
# Epoch  128 : Loss : 0.2074, Acc : 1.0000, Test Acc : 0.9520
# Epoch  129 : Loss : 0.2065, Acc : 1.0000, Test Acc : 0.9520
# Epoch  130 : Loss : 0.2057, Acc : 1.0000, Test Acc : 0.9520
# Epoch  131 : Loss : 0.2048, Acc : 1.0000, Test Acc : 0.9520
# Epoch  132 : Loss : 0.2040, Acc : 1.0000, Test Acc : 0.9520
# Epoch  133 : Loss : 0.2031, Acc : 1.0000, Test Acc : 0.9520
# Epoch  134 : Loss : 0.2023, Acc : 1.0000, Test Acc : 0.9520
# Epoch  135 : Loss : 0.2014, Acc : 1.0000, Test Acc : 0.9520
# Epoch  136 : Loss : 0.2006, Acc : 1.0000, Test Acc : 0.9520
# Epoch  137 : Loss : 0.1998, Acc : 1.0000, Test Acc : 0.9520
# Epoch  138 : Loss : 0.1990, Acc : 1.0000, Test Acc : 0.9520
# Epoch  139 : Loss : 0.1982, Acc : 1.0000, Test Acc : 0.9520
# Epoch  140 : Loss : 0.1974, Acc : 1.0000, Test Acc : 0.9520
# Epoch  141 : Loss : 0.1966, Acc : 1.0000, Test Acc : 0.9520
# Epoch  142 : Loss : 0.1958, Acc : 1.0000, Test Acc : 0.9520
# Epoch  143 : Loss : 0.1950, Acc : 1.0000, Test Acc : 0.9520
# Epoch  144 : Loss : 0.1943, Acc : 1.0000, Test Acc : 0.9520
# Epoch  145 : Loss : 0.1935, Acc : 1.0000, Test Acc : 0.9520
# Epoch  146 : Loss : 0.1928, Acc : 1.0000, Test Acc : 0.9520
# Epoch  147 : Loss : 0.1920, Acc : 1.0000, Test Acc : 0.9520
# Epoch  148 : Loss : 0.1913, Acc : 1.0000, Test Acc : 0.9520
# Epoch  149 : Loss : 0.1905, Acc : 1.0000, Test Acc : 0.9520

# %%
from mlxtend.plotting import plot_decision_regions

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 13s 1ms/step

# %% [markdown]
# Une fois cette étape réalisée, vous pouvez tester l'algorithme sur le dataset des 2 lunes ; comme annoncé en cours, vous devriez avoir beaucoup de mal à faire fonctionner l'algorithme sur ces données.
#
# S'il vous reste du temps, vous pouvez également tester votre algorithme sur les données MNIST, cela vous avancera pour la prochaine séance.

# %%
import tensorflow as tf
from tensorflow import keras
import math

lambda_t = 0

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2moons()

# Hyperparamètres de l'apprentissage
epochs = 150
batch_size = 16
batch_size_unlab = 90
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices_lab = np.arange(x_train_lab.shape[0])
indices_unlab = np.arange(x_train_unlab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices_lab)
  np.random.shuffle(indices_unlab)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices_lab[step*batch_size: (step+1)*batch_size]]
    y_batch = y_train_lab[indices_lab[step*batch_size: (step+1)*batch_size]]
    x_batch_unlab = x_train_unlab[indices_unlab[step*batch_size_unlab: (step+1)*batch_size_unlab]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch
      y_pred_unlab = model(x_batch_unlab, training=True)

      # Calcul de la fonction de perte sur ce batch
      sup_term = loss_fn(y_batch, y_pred)
      unsup_term = binary_entropy_loss(y_pred_unlab)

      loss_value = sup_term + unsup_term

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_states()
  test_acc_metric.reset_states()

  # Mise à jour du paramètre de contrôle de l'importance de la régularisation non-supervisée
  # Il augmente progressivement !
  if lambda_t < 1:
    if epoch > 100:
      lambda_t = lambda_t + 0.01
# Out:
# Epoch    0 : Loss : 1.4475, Acc : 0.3000, Test Acc : 0.4520
# Epoch    1 : Loss : 1.4185, Acc : 0.3000, Test Acc : 0.4360
# Epoch    2 : Loss : 1.3882, Acc : 0.2000, Test Acc : 0.4800
# Epoch    3 : Loss : 1.3577, Acc : 0.3000, Test Acc : 0.5800
# Epoch    4 : Loss : 1.3343, Acc : 0.8000, Test Acc : 0.7880
# Epoch    5 : Loss : 1.3100, Acc : 0.9000, Test Acc : 0.7920
# Epoch    6 : Loss : 1.2837, Acc : 0.9000, Test Acc : 0.7920
# Epoch    7 : Loss : 1.2597, Acc : 0.9000, Test Acc : 0.7920
# Epoch    8 : Loss : 1.2253, Acc : 0.9000, Test Acc : 0.7920
# Epoch    9 : Loss : 1.2028, Acc : 0.9000, Test Acc : 0.7920
# Epoch   10 : Loss : 1.1647, Acc : 0.9000, Test Acc : 0.7920
# Epoch   11 : Loss : 1.1397, Acc : 0.9000, Test Acc : 0.7920
# Epoch   12 : Loss : 1.1230, Acc : 0.9000, Test Acc : 0.7920
# Epoch   13 : Loss : 1.0889, Acc : 0.9000, Test Acc : 0.7920
# Epoch   14 : Loss : 1.0653, Acc : 0.9000, Test Acc : 0.7920
# Epoch   15 : Loss : 1.0561, Acc : 0.9000, Test Acc : 0.7920
# Epoch   16 : Loss : 1.0072, Acc : 0.8000, Test Acc : 0.7960
# Epoch   17 : Loss : 0.9737, Acc : 0.8000, Test Acc : 0.8040
# Epoch   18 : Loss : 0.9458, Acc : 0.8000, Test Acc : 0.8040
# Epoch   19 : Loss : 0.9512, Acc : 0.8000, Test Acc : 0.8040
# Epoch   20 : Loss : 0.9170, Acc : 0.8000, Test Acc : 0.8040
# Epoch   21 : Loss : 0.8874, Acc : 0.8000, Test Acc : 0.8040
# Epoch   22 : Loss : 0.8426, Acc : 0.8000, Test Acc : 0.8040
# Epoch   23 : Loss : 0.8425, Acc : 0.8000, Test Acc : 0.8040
# Epoch   24 : Loss : 0.8186, Acc : 0.8000, Test Acc : 0.8040
# Epoch   25 : Loss : 0.7761, Acc : 0.8000, Test Acc : 0.8080
# Epoch   26 : Loss : 0.7768, Acc : 0.8000, Test Acc : 0.8080
# Epoch   27 : Loss : 0.7782, Acc : 0.8000, Test Acc : 0.8080
# Epoch   28 : Loss : 0.7404, Acc : 0.8000, Test Acc : 0.8080
# Epoch   29 : Loss : 0.7154, Acc : 0.8000, Test Acc : 0.8080
# Epoch   30 : Loss : 0.7212, Acc : 0.8000, Test Acc : 0.8080
# Epoch   31 : Loss : 0.7013, Acc : 0.8000, Test Acc : 0.8080
# Epoch   32 : Loss : 0.6462, Acc : 0.8000, Test Acc : 0.8080
# Epoch   33 : Loss : 0.6380, Acc : 0.8000, Test Acc : 0.8080
# Epoch   34 : Loss : 0.6447, Acc : 0.8000, Test Acc : 0.8080
# Epoch   35 : Loss : 0.6320, Acc : 0.8000, Test Acc : 0.8080
# Epoch   36 : Loss : 0.6463, Acc : 0.8000, Test Acc : 0.8080
# Epoch   37 : Loss : 0.6412, Acc : 0.8000, Test Acc : 0.8080
# Epoch   38 : Loss : 0.6019, Acc : 0.8000, Test Acc : 0.8080
# Epoch   39 : Loss : 0.6282, Acc : 0.8000, Test Acc : 0.8080
# Epoch   40 : Loss : 0.5780, Acc : 0.8000, Test Acc : 0.8080
# Epoch   41 : Loss : 0.6326, Acc : 0.8000, Test Acc : 0.8080
# Epoch   42 : Loss : 0.5835, Acc : 0.8000, Test Acc : 0.8080
# Epoch   43 : Loss : 0.6035, Acc : 0.8000, Test Acc : 0.8080
# Epoch   44 : Loss : 0.5734, Acc : 0.8000, Test Acc : 0.8080
# Epoch   45 : Loss : 0.5539, Acc : 0.8000, Test Acc : 0.8120
# Epoch   46 : Loss : 0.5755, Acc : 0.8000, Test Acc : 0.8120
# Epoch   47 : Loss : 0.5939, Acc : 0.8000, Test Acc : 0.8120
# Epoch   48 : Loss : 0.5770, Acc : 0.8000, Test Acc : 0.8120
# Epoch   49 : Loss : 0.5789, Acc : 0.8000, Test Acc : 0.8120
# Epoch   50 : Loss : 0.5509, Acc : 0.8000, Test Acc : 0.8120
# Epoch   51 : Loss : 0.5578, Acc : 0.8000, Test Acc : 0.8120
# Epoch   52 : Loss : 0.5742, Acc : 0.8000, Test Acc : 0.8120
# Epoch   53 : Loss : 0.5471, Acc : 0.8000, Test Acc : 0.8160
# Epoch   54 : Loss : 0.5614, Acc : 0.8000, Test Acc : 0.8160
# Epoch   55 : Loss : 0.5052, Acc : 0.8000, Test Acc : 0.8160
# Epoch   56 : Loss : 0.5179, Acc : 0.8000, Test Acc : 0.8160
# Epoch   57 : Loss : 0.5605, Acc : 0.8000, Test Acc : 0.8160
# Epoch   58 : Loss : 0.5159, Acc : 0.8000, Test Acc : 0.8160
# Epoch   59 : Loss : 0.5424, Acc : 0.8000, Test Acc : 0.8200
# Epoch   60 : Loss : 0.5354, Acc : 0.8000, Test Acc : 0.8240
# Epoch   61 : Loss : 0.5321, Acc : 0.8000, Test Acc : 0.8240
# Epoch   62 : Loss : 0.5330, Acc : 0.8000, Test Acc : 0.8280
# Epoch   63 : Loss : 0.4883, Acc : 0.8000, Test Acc : 0.8280
# Epoch   64 : Loss : 0.4919, Acc : 0.8000, Test Acc : 0.8320
# Epoch   65 : Loss : 0.4909, Acc : 0.8000, Test Acc : 0.8320
# Epoch   66 : Loss : 0.5032, Acc : 0.8000, Test Acc : 0.8400
# Epoch   67 : Loss : 0.5135, Acc : 0.8000, Test Acc : 0.8440
# Epoch   68 : Loss : 0.4760, Acc : 0.8000, Test Acc : 0.8440
# Epoch   69 : Loss : 0.4816, Acc : 0.8000, Test Acc : 0.8440
# Epoch   70 : Loss : 0.4578, Acc : 0.8000, Test Acc : 0.8440
# Epoch   71 : Loss : 0.4434, Acc : 0.8000, Test Acc : 0.8440
# Epoch   72 : Loss : 0.4765, Acc : 0.8000, Test Acc : 0.8440
# Epoch   73 : Loss : 0.4571, Acc : 0.8000, Test Acc : 0.8440
# Epoch   74 : Loss : 0.4527, Acc : 0.8000, Test Acc : 0.8440
# Epoch   75 : Loss : 0.4740, Acc : 0.8000, Test Acc : 0.8440
# Epoch   76 : Loss : 0.4272, Acc : 0.8000, Test Acc : 0.8440
# Epoch   77 : Loss : 0.4039, Acc : 0.8000, Test Acc : 0.8440
# Epoch   78 : Loss : 0.4680, Acc : 0.8000, Test Acc : 0.8480
# Epoch   79 : Loss : 0.4040, Acc : 0.8000, Test Acc : 0.8480
# Epoch   80 : Loss : 0.3928, Acc : 0.8000, Test Acc : 0.8440
# Epoch   81 : Loss : 0.4145, Acc : 0.8000, Test Acc : 0.8440
# Epoch   82 : Loss : 0.4685, Acc : 0.8000, Test Acc : 0.8440
# Epoch   83 : Loss : 0.3938, Acc : 0.8000, Test Acc : 0.8440
# Epoch   84 : Loss : 0.4101, Acc : 0.8000, Test Acc : 0.8440
# Epoch   85 : Loss : 0.3994, Acc : 0.8000, Test Acc : 0.8440
# Epoch   86 : Loss : 0.4142, Acc : 0.8000, Test Acc : 0.8480
# Epoch   87 : Loss : 0.4329, Acc : 0.8000, Test Acc : 0.8520
# Epoch   88 : Loss : 0.3993, Acc : 0.8000, Test Acc : 0.8600
# Epoch   89 : Loss : 0.3862, Acc : 0.8000, Test Acc : 0.8600
# Epoch   90 : Loss : 0.4184, Acc : 0.8000, Test Acc : 0.8600
# Epoch   91 : Loss : 0.3808, Acc : 0.8000, Test Acc : 0.8680
# Epoch   92 : Loss : 0.4043, Acc : 0.8000, Test Acc : 0.8680
# Epoch   93 : Loss : 0.3772, Acc : 0.8000, Test Acc : 0.8680
# Epoch   94 : Loss : 0.4166, Acc : 0.8000, Test Acc : 0.8680
# Epoch   95 : Loss : 0.3918, Acc : 0.8000, Test Acc : 0.8680
# Epoch   96 : Loss : 0.3663, Acc : 0.8000, Test Acc : 0.8720
# Epoch   97 : Loss : 0.3511, Acc : 0.8000, Test Acc : 0.8720
# Epoch   98 : Loss : 0.3949, Acc : 0.8000, Test Acc : 0.8720
# Epoch   99 : Loss : 0.3662, Acc : 0.8000, Test Acc : 0.8720
# Epoch  100 : Loss : 0.3952, Acc : 0.8000, Test Acc : 0.8720
# Epoch  101 : Loss : 0.3738, Acc : 0.8000, Test Acc : 0.8720
# Epoch  102 : Loss : 0.3381, Acc : 0.8000, Test Acc : 0.8760
# Epoch  103 : Loss : 0.4129, Acc : 0.8000, Test Acc : 0.8760
# Epoch  104 : Loss : 0.3633, Acc : 0.8000, Test Acc : 0.8760
# Epoch  105 : Loss : 0.3931, Acc : 0.8000, Test Acc : 0.8760
# Epoch  106 : Loss : 0.3656, Acc : 0.8000, Test Acc : 0.8760
# Epoch  107 : Loss : 0.3417, Acc : 0.8000, Test Acc : 0.8760
# Epoch  108 : Loss : 0.3444, Acc : 0.8000, Test Acc : 0.8760
# Epoch  109 : Loss : 0.3611, Acc : 0.8000, Test Acc : 0.8760
# Epoch  110 : Loss : 0.3300, Acc : 0.8000, Test Acc : 0.8760
# Epoch  111 : Loss : 0.3694, Acc : 0.8000, Test Acc : 0.8800
# Epoch  112 : Loss : 0.3240, Acc : 0.8000, Test Acc : 0.8800
# Epoch  113 : Loss : 0.3633, Acc : 0.8000, Test Acc : 0.8800
# Epoch  114 : Loss : 0.3535, Acc : 0.8000, Test Acc : 0.8840
# Epoch  115 : Loss : 0.3388, Acc : 0.8000, Test Acc : 0.8840
# Epoch  116 : Loss : 0.3349, Acc : 0.8000, Test Acc : 0.8840
# Epoch  117 : Loss : 0.3411, Acc : 0.8000, Test Acc : 0.8840
# Epoch  118 : Loss : 0.3228, Acc : 0.8000, Test Acc : 0.8840
# Epoch  119 : Loss : 0.3307, Acc : 0.8000, Test Acc : 0.8840
# Epoch  120 : Loss : 0.3191, Acc : 0.8000, Test Acc : 0.8840
# Epoch  121 : Loss : 0.3163, Acc : 0.8000, Test Acc : 0.8880
# Epoch  122 : Loss : 0.3243, Acc : 0.8000, Test Acc : 0.8920
# Epoch  123 : Loss : 0.3223, Acc : 0.8000, Test Acc : 0.8920
# Epoch  124 : Loss : 0.2773, Acc : 0.8000, Test Acc : 0.8920
# Epoch  125 : Loss : 0.3357, Acc : 0.8000, Test Acc : 0.8920
# Epoch  126 : Loss : 0.2941, Acc : 0.8000, Test Acc : 0.8920
# Epoch  127 : Loss : 0.2986, Acc : 0.8000, Test Acc : 0.8920
# Epoch  128 : Loss : 0.3345, Acc : 0.8000, Test Acc : 0.8960
# Epoch  129 : Loss : 0.2780, Acc : 0.8000, Test Acc : 0.8960
# Epoch  130 : Loss : 0.3042, Acc : 0.8000, Test Acc : 0.8960
# Epoch  131 : Loss : 0.3327, Acc : 0.8000, Test Acc : 0.8960
# Epoch  132 : Loss : 0.3308, Acc : 0.8000, Test Acc : 0.9000
# Epoch  133 : Loss : 0.2865, Acc : 0.8000, Test Acc : 0.9000
# Epoch  134 : Loss : 0.3198, Acc : 0.8000, Test Acc : 0.9000
# Epoch  135 : Loss : 0.3075, Acc : 0.8000, Test Acc : 0.9000
# Epoch  136 : Loss : 0.2954, Acc : 0.8000, Test Acc : 0.9000
# Epoch  137 : Loss : 0.2489, Acc : 0.8000, Test Acc : 0.9040
# Epoch  138 : Loss : 0.2883, Acc : 0.8000, Test Acc : 0.9040
# Epoch  139 : Loss : 0.3233, Acc : 0.8000, Test Acc : 0.9040
# Epoch  140 : Loss : 0.2833, Acc : 0.8000, Test Acc : 0.9040
# Epoch  141 : Loss : 0.2893, Acc : 0.8000, Test Acc : 0.9040
# Epoch  142 : Loss : 0.3130, Acc : 0.8000, Test Acc : 0.9040
# Epoch  143 : Loss : 0.3127, Acc : 0.8000, Test Acc : 0.9040
# Epoch  144 : Loss : 0.3079, Acc : 0.8000, Test Acc : 0.9040
# Epoch  145 : Loss : 0.2992, Acc : 0.8000, Test Acc : 0.9040
# Epoch  146 : Loss : 0.2792, Acc : 0.8000, Test Acc : 0.9040
# Epoch  147 : Loss : 0.3079, Acc : 0.8000, Test Acc : 0.9000
# Epoch  148 : Loss : 0.2503, Acc : 0.8000, Test Acc : 0.9040
# Epoch  149 : Loss : 0.2971, Acc : 0.8000, Test Acc : 0.9040

# %%
from mlxtend.plotting import plot_decision_regions

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 15s 2ms/step

# %% [markdown]
# # MNIST

# %% [markdown]
# ## Chargement des données

# %%
from tensorflow.keras.datasets import mnist
import numpy as np
from sklearn.model_selection import train_test_split

def generate_mnist_dataset(num_lab = 10):

  # Chargement et normalisation (entre 0 et 1) des données de la base de données MNIST
  (x_train, y_train), (x_test, y_test) = mnist.load_data()

  x_train = np.expand_dims(x_train.astype('float32') / 255., 3)
  x_test = np.expand_dims(x_test.astype('float32') / 255., 3)

  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=(x_train.shape[0]-num_lab)/x_train.shape[0], random_state=2)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test

# %%
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_mnist_dataset(num_lab = 10)

print(x_train_lab.shape, x_train_unlab.shape, x_test.shape)
print(y_train_lab.shape, y_train_unlab.shape, y_test.shape)

# %% [markdown]
# ## Définition du modèle

# %%
# A COMPLETER
# Ici, on implémentera le modèle LeNet-5 :
# 1 couche de convolution 5x5 à 6 filtres suivie d'un max pooling
# puis 1 couche de convolution 5x5 à 16 filtres suivie d'un max pooling et d'un Flatten
# Enfin 2 couches denses de 120 et 84 neurones, avant la couche de sortie à 10 neurones.
def create_model_mnist():

  inputs = keras.Input(shape=(28, 28, 1))  # images MNIST 28x28 avec 1 canal (niveau de gris).

  x = Conv2D(6, kernel_size=(5, 5), activation='relu')(inputs)
  x = MaxPooling2D(pool_size=(2, 2))(x)

  x = Conv2D(16, kernel_size=(5, 5), activation='relu')(x)
  x = MaxPooling2D(pool_size=(2, 2))(x)
  x = Flatten()(x)

  x = Dense(120, activation='relu')(x)
  x = Dense(84, activation='relu')(x)
  outputs = Dense(10, activation='softmax')(x)

  model = keras.Model(inputs=inputs, outputs=outputs)

  return model
